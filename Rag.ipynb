# %%
import pandas as pd

# %%
file_path='Enter your file path'

# %%
df=pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Serial No.  SC Decision                                      Project Title  \
# 0           2  Recommended  Energy Storage and Trading for Smart Grids: Le...
# 1           3  Recommended  Embedded AI Based Real Time Circuit Breaker He...
# 2           4  Recommended  Smart Farming: An Intelligent Crop Recommendat...
# 3           5  Recommended          Banking Guard: Counterfeit Fraud Using ML
# 4           6  Recommended  AI-Driven Predictive Maintenance of  Induction...
#
#                              Scientist  Organization  \
# 0                         National Skills University
# 1                         National Skills University
# 2                    University of Agriculture (FSD)
# 3                        Superior University, Lahore
# 4  Pakistan Institute of Nuclear Science &amp; Te...
#
#   Concept Proposal Paper Discipline / Sector Involved  \
# 0                            Artificial intelligence
# 1                            Artificial intelligence
# 2                            Artificial intelligence
# 3                            Artificial intelligence
# 4                            Artificial intelligence
#
#    Concept Proposal Duration Concept Proposal Paper Proposed Solution  \
# 0                        2.0                                 Products
# 1                        2.0                             Technologies
# 2                        2.0                           Value-Addition
# 3                        1.0                                 Products
# 4                        2.0                               Techniques
#
#                                           Objectives  \
# 0  1) The proposed system seeks to meet the needs...
# 1  1)The suggested embedded AI-based real-time he...
# 2  •To build an intelligent device to help farmer...
# 3  •Developing and deploying a fraud detection sy...
# 4  •To demonstrate the feasibility of artificial ...
#
#                               Methodology/Activities  \
# 0  Data collection, AI model development, device ...
# 1  Stages of this project's methodology:\n1. Syst...
# 2  Data collection: The device would collect data...
# 3  Some common activities performed in a project ...
# 4  For the successful implementation of the propo...
#
#                              Outcomes (Quantifiable)  \
# 0  The quantifiable results of an AI-based device...
# 1  Quantifiable results\nThe integrated AI-based ...
# 2  I.Increased crop yield: A crop recommendation ...
# 3  •Reduced financial losses: By detecting and pr...
# 4  •minimize maintenance costs by 25%\n•approxima...
#
#    Estimated Budget (in millions)
# 0                             9.0
# 1                             9.0
# 2                             7.0
# 3                             3.0
# 4                             1.5

# %%
from langchain_ollama import OllamaEmbeddings
from langchain.vectorstores import FAISS

# Combine textual columns for embedding
textual_columns = [
    "Project Title",
    "Objectives",
    "Methodology/Activities",
    "Outcomes (Quantifiable)",
    "Concept Proposal Paper Discipline / Sector Involved",
]
df['combined_text'] = df[textual_columns].fillna('').agg(' '.join, axis=1)

# %%
from langchain_ollama import OllamaEmbeddings
# Generate embeddings for combined textual data
embedding_model = OllamaEmbeddings(model="nomic-embed-text")

# %%
from langchain.schema import Document

# Wrap each row of text in a Document object
documents = [
    Document(page_content=row) for row in df['combined_text'].tolist()
]

# %%
from langchain.vectorstores import FAISS

# Create the FAISS index using the embedding model
vector_store = FAISS.from_documents(documents=documents, embedding=embedding_model)

# %%
vector_store.search(query = """
Write any query here to check if vectorstore is working properly or not?
""",search_type="mmr")
# Out:
# [Document(metadata={}, page_content="Photo Catalytic Hydrogen Generation Using Metal Oxide Based Heterostructure Through Water Splitting In order to tackle the global energy crisis, Z- scheme H2 production is one of the most effective solutions.\n        Despite developments in  Z-scheme photocatalytic H2 production, this field still faces difficulties such as \n•(1) limited efficiency of photocatalytic H2 production \n•(2) fast recombination of electron-hole pairs \n•(3) inadequate selectivity, suggesting costly detachment measures, and \n•(4) The wideband in harvesting visible light photocatalyst, limiting practical use and technology. \n•Additionally, their large-scale applications are hampered by the deficiency and high cost of noble metal catalysts (Pt, Au, and Pd). Increased study attempts have concentrated on these situations to design and synthesize novel, cost-effective, and sturdy photocatalysts that can improve H2 production efficiency at low prices with minimal over-potential\n Phase 1: Synthesis\nGO will be prepared by the Hummers method, CNTs will be synthesized by the catalytic decomposition process, and the g-C3N4 nanosheets (shorted as CN) will be fabricated by annealing urea at 550 °C. The metal oxide and dichalcogenides solutions will be prepared by mixing their precursor’s solution drop-wise while keeping on normal stirring. The GO and CNTs will be then introduced to the mixed solutions and will be shifted to the Teflon lined stainless steel autoclave. The autoclave will be heated hydrothermally in a vacuum oven at 200 oC for 24 hrs. The obtained samples will then be washed several times with distilled water and dried overnight.\nPhase 2: Electrochemical Measurements\n10 mg of the prepared photocatalyst is dissolved in 250 μL ethylene glycol, 250 μL of absolute ethanol, and 40 μL of coating solution and sonicated for 1 hour. Afterward, the solution is pasted on ITO and dried in the oven at 70 oC for 5 hours. Then the linear sweep voltammetry (LSV), Mott-Schottky curves (M-S), photocurrents (PC) and electrochemical impedance spectroscopy (EIS) of the catalysts were tested on an electrochemical workstation (CHI–660E, Shanghai, China) having platinum plate (counter electrode),  Ag/AgCl (reference electrode) and 0.5 M Na2SO4 solution as the supporting electrolyte. \uf076Supply clean fuels and electricity securely to satisfy the world's increasing demand.\n\uf076Eliminate pollution issues with the environment and stabilize greenhouse gas (GHG) emissions from energy utilization.\n\uf076Increase power effectiveness by creating new power technologies to overcome the current wasteful power system’s thermodynamic boundaries.\n\uf076Sustainable and secure energy development, including renewable energy.\n\uf076Sustainable development of organic materials with carbon-based feedstock. Material"),
#  Document(metadata={}, page_content='Designing of Wind-Solar Hybrid Energy Forecasting Model using Machine Learning Techniques for Pakistan. The main objectives of the proposed study are as follows:\n•To prepare a model for the estimation of electricity production at Jhimpir region, which is declared as most favorable are for wind based power generation.\n•To study different parameters like wind speed, solar irradiance, temperature in relevance to wind-solar hybrid energy.\n•To conduct a comparative study independently and combined for optimal solution of high energy generation using machine learning techniques. 1: Literature survey and data collection. \n2: Procurement/tender for main equipment. \n3: Installation, civil work and initialize data pre-processing. \n4: Procurement of remaining equipment and finalize pre-processing. \n5: Data analysis for selection of algorithm means different test of statistics were applied. \n6: Machine Leaning and associated Algorithms were examined. \n7: Comparative study of said algorithm. \n8: Research dissemination in form of seminar(s) &amp; research publication(s). Following are the foreseen outcomes of the proposed study:\n•The results and developed model expected to help renewable energy sector, energy research &amp; development organizations and will have long lasting clean and green environment and economic impact.\n•Many windfarms are in operation at different regions of Pakistan where they spend huge amount of maintenance either windfarm are running or not. In case of this work, the confidence level of investor/ industrialist increases to establish wind-solar hybrid farm, which will be the first step towards energy mix concept maturity in the Country. \n•Development of model enhance machine learning energy research activities in the country where human resource trained, which will be a step towards self-sustainability.\n•Performance of renewable energy sector improves by adding such research will eventually enhance confidence on  machine learning techniques. \n•Results and research work of data scientists of Pakistan will be recognized and can easily be publish on international forum.\n•Electricity generation sector will be benefited by improving renewable energy production capabilities with accuracy. Artificial intelligence'),
#  Document(metadata={}, page_content='Design and Development of Commercial of the Shelf (COTS) Vertical Wind Turbine System To produce renewable energy power that small home can utilize\nTo help reduce green house gas emissions contributing to climate change\nReduce reliance on fossil fuels and carbon emissions Conduct literature reviews and identify key design parameters\nDevelop and optimize the design of the turbine using CAD /CAM software\nConduct computational simulations and experimental testing of the turbine design \nBuild a prototype turbine and conduct field testing \nAnalyze the economic and environmental feasibility of the turbine \nRefine the design of the turbine based on feedback from field testing and economic analysis \nDevelop recommendations for future research and potential commercialization of the turbine Can Deliver upto 20kwh/day \nCompact size ranging upto 9 feet\nCan provide maximum efficacy when installed at least 30 feet above ground level. Material'),
#  Document(metadata={}, page_content='Photovoltaic interfaced grid-tie generation system for residential buildings: conception, control, and realtime monitoring \nThe tentative objectives are as follows:\n\n-- Conceptualizing an analytically generic method for designing and sizing the component of PV interfaced grid-tie power system.\n-- Synthesizing a real-time optimal control and energy management of PV interfaced grid-tie system.\n-- Developing a comprehensive simulation framework for investigating the performance of such systems.\n-- Designing a domestic-scale moderate system by exploiting the available resources, as well as procuring the appropriate equipment using the available budget.\n-- Perform long-term real-time monitoring of the conceptualized system for public awareness and robust engineering perspective. The project will initiate with an effective feasibility study, including present and future load demand, as well as the cost factor and expected outcomes. The study will lead to an analytic approach for designing the grid-tie PV systems, such that the ownership price is reduced and nominal performance is retained under diverse scenarios. The next activity would be to synthesize real-time optimal energy management of the designed system. This energy management would stand uniquely amongst market-based simplistic solutions owing to its optimal nature. The overall methodology would facilitate a robust switching framework among generational sources depending on the state of load, grid, and battery. It will also take into account the uncertainties (load, source, weather, etc.). The existing system will be properly expanded to encompass this study and to meet the future load demand.\nFinally, the performance of the proposed system will be monitored under real-time scenarios for at least a year, including seasonal variations and uncertainties at both load and generation end. The monitored data will be saved and interpreted in the form of a feasibility report which will not only be shared with the scientific community but with academia, and industry, and will also be available for public usage. -- Preparation of an authentic database and associated literature providing real-time resource profiles and relevant operational schemes.\n-- A robust and flexible simulator for investigating the performance of PV systems on virtual grounds.\n-- Design and development of moderate power prototype for residential applications.\n-- Synthesize an optimal energy management system with real-time monitoring system.\n-- Generation of feasibility reports for the scientific community, academia, industry, and public usage. Artificial intelligence')]

# %%
from langchain_ollama import OllamaLLM

# Initialize the Ollama LLM
llm = OllamaLLM(model="llama3.1")

# %%
evaluator_prompt = """ 
You are an expert evaluator for research grant applications. Your task is to analyze the provided project proposal and compare it with similar projects from a dataset. For each of the aspects outlined below, you will need to provide:

1. A similarity score (0% to 100%) indicating how closely the project matches existing projects in the dataset.
2. A detailed analysis of whether the project is unique or redundant, with a focus on what differentiates it or aligns it with existing work.
3. If the project is unique, highlight specific innovative or novel aspects that make it stand out and explain how these features enhance its chances of receiving a grant.
4. If the project is highly similar to existing ones, provide a brief explanation of how this redundancy may affect the likelihood of grant approval, and suggest areas for improvement to reduce overlap and increase uniqueness.

Aspects to analyze:
- **Project Title**: Does the title reflect innovation or does it echo similar projects? Is the title clear and impactful for potential stakeholders?
- **Objectives**: Are the objectives clearly defined and realistic? How do the objectives differentiate this project from others in terms of ambition or relevance?
- **Methodology/Activities**: Assess whether the methodology is novel and grounded in strong scientific principles, or if it closely mirrors existing methods. Is there a unique approach to solving the problem?
- **Outcomes (Quantifiable)**: How measurable and impactful are the expected outcomes? Are these outcomes aligned with key grant criteria, such as societal relevance, scalability, and feasibility? How does this compare to similar projects?
- **Discipline/Sector Involved**: Does the project address an underserved sector or a new discipline? Does it bring a fresh perspective or contribution to a well-established field?

Additionally, you will need to:
- **Generate a structured summary** of similarity scores for each aspect, formatted for easy visualization (e.g., as a table or in a structured report).
- **Grant Recommendation**: Provide a final recommendation on whether the project is suitable for grant approval based on your analysis of its uniqueness and similarity. Include any actionable feedback on improving the project's chances of approval, especially in terms of enhancing its uniqueness or addressing any gaps identified.

Input Project:
{query}

Similar Projects:
{similar_projects}

Expected Output:
1. A detailed similarity report for each aspect, including:
   - Similarity percentage score (0% to 100%) for each aspect.
   - In-depth analysis of uniqueness or redundancy for each aspect.
   - Clear differentiation of innovative features if the project is unique.
2. A summary table of similarity scores for easy graph generation (include categories like "Project Title," "Objectives," etc.).
#### Summary Table of Similarity Scores
```markdown
| Aspect                  | Similarity Score (%) |
|-------------------------|----------------------|
| Project Title           | [Score]             |
| Objectives              | [Score]             |
| Methodology/Activities  | [Score]             |
| Outcomes (Quantifiable) | [Score]             |
| Discipline/Sector       | [Score]             |

3. A final evaluation and recommendation for the grant decision, based on the overall uniqueness and relevance of the project. Include any suggestions for improving the project if it is too similar to existing ones.
"""

# %%
student_prompt = """
You are an assistant for evaluating the likelihood of grant approval for a given project. Assess the project's similarity to previous projects in the dataset and calculate the likelihood of grant approval. Provide a detailed and balanced evaluation based on the following considerations:
1. Higher similarity with previous projects reduces the likelihood of grant approval.
2. Unique and innovative features significantly increase the chances of grant approval (up to 80-90% if the project is highly unique).
3. Consider how well the project addresses unmet needs or gaps in the dataset.

Input Details:
- Input Project: {query}
- Similar Projects: {similar_projects}

Your task:
1. Analyze the similarity of the project to previous projects and describe how it impacts the chances of approval.
2. Highlight any innovative or unique aspects that may positively influence the decision. If the project is deemed highly unique, assign a grant likelihood score of 80-90%.
3. Provide actionable suggestions for further improvements to enhance the project's chances of grant approval.
4. Address areas where the project could reduce redundancy or better align with unmet needs in the dataset.

Output:
- A clear and concise likelihood evaluation in percentages.
- A brief explanation of factors influencing the score, including both positive (e.g., uniqueness) and negative (e.g., redundancy) aspects.
- Actionable suggestions to improve the project for resubmission, focusing on enhancing innovation and addressing gaps.
- For highly unique projects, explicitly state why the likelihood score is 80-90%, supported by detailed reasoning.
"""

# %%
# Simulated project input
query = """
Developing a smart irrigation system powered by AI and IoT to optimize water usage in agriculture. 
The project aims to reduce water wastage and improve crop yield through automated real-time monitoring and control systems.

"""

# Query embedding
query_embedding = embedding_model.embed_query(query)

# Retrieve similar projects
results = vector_store.similarity_search_by_vector(query_embedding, k=3)
similar_projects = "\n".join([res.page_content for res in results])

# Generate evaluator's report
evaluator_report = llm.invoke(
    evaluator_prompt.format(query=query, similar_projects=similar_projects)
)

# Generate student's likelihood report
student_report = llm.invoke(
    student_prompt.format(query=query, similar_projects=similar_projects)
)

# Output results
print("Evaluator's Perspective:")
print(evaluator_report)
print("\n" + "=" * 50 + "\n")
print("Student's Perspective:")
print(student_report)
# Out:
# Evaluator's Perspective:
# **Similarity Report**
#
# ### Project Title
# The project title "Design and Development of Artificial Intelligence Based Solar Automatic Drip Irrigation System" has a similarity score of 80%.
#
# * Similar projects: Design and development of Artificial intelligence based solar automatic drip irrigation system (85% match), Automated solar based drip irrigation system for agricultural fields of Pakistan (90% match)
# * Uniqueness: The project title is similar to existing ones, but with a unique twist in incorporating artificial intelligence.
#
# ### Objectives
# The objectives of the project have a similarity score of 75%.
#
# * Similar projects: Design and development of Artificial intelligence based solar automatic drip irrigation system (80% match), Automated solar based drip irrigation system for agricultural fields of Pakistan (85% match)
# * Uniqueness: The objectives are similar to existing ones, but with a focus on artificial intelligence.
#
# ### Methodology/Activities
# The methodology and activities of the project have a similarity score of 70%.
#
# * Similar projects: Design and development of Artificial intelligence based solar automatic drip irrigation system (75% match), Automated solar based drip irrigation system for agricultural fields of Pakistan (80% match)
# * Uniqueness: The methodology is similar to existing ones, but with a unique approach in using artificial intelligence.
#
# ### Outcomes (Quantifiable)
# The outcomes of the project have a similarity score of 65%.
#
# * Similar projects: Design and development of Artificial intelligence based solar automatic drip irrigation system (70% match), Automated solar based drip irrigation system for agricultural fields of Pakistan (75% match)
# * Uniqueness: The outcomes are similar to existing ones, but with a unique focus on energy savings and labor cost reduction.
#
# ### Discipline/Sector
# The discipline and sector of the project have a similarity score of 60%.
#
# * Similar projects: Design and development of Artificial intelligence based solar automatic drip irrigation system (65% match), Automated solar based drip irrigation system for agricultural fields of Pakistan (70% match)
# * Uniqueness: The discipline and sector are similar to existing ones, but with a unique focus on artificial intelligence.
#
# **Summary Table of Similarity Scores**
#
# | Aspect                  | Similarity Score (%) |
# |-------------------------|----------------------|
# | Project Title           | 80%                 |
# | Objectives              | 75%                 |
# | Methodology/Activities  | 70%                 |
# | Outcomes (Quantifiable) | 65%                 |
# | Discipline/Sector       | 60%                 |
#
# **Final Evaluation and Recommendation**
#
# Based on the overall similarity scores, it is recommended to consider this project for a grant decision. However, there are suggestions to improve the project by:
#
# * Adding more unique features that differentiate it from existing projects.
# * Emphasizing the benefits of artificial intelligence in agriculture.
# * Providing more detailed information on energy savings and labor cost reduction.
#
# **Recommendation**
#
# Grant Decision: Consider for funding with modifications to make it more unique and relevant.
#
# Note: The scores are based on a subjective assessment of the similarity between the project and existing ones. The actual scores may vary depending on the specific context and criteria used.
#
# ==================================================
#
# Student's Perspective:
# **Likelihood of Grant Approval: 70%**
#
# The project's similarity to previous initiatives negatively impacts its chances of approval. However, it also has some innovative aspects that could positively influence the decision.
#
# **Similarity to Previous Projects (Negative Impact): 20%**
#
# The proposed project shares many similarities with existing research on AI-enabled irrigation systems and automated drip irrigation systems for agricultural fields in Pakistan. Specifically:
#
# 1. The use of solar power and wireless sensors is a common theme among previous projects.
# 2. The integration of AI algorithms for water quantity control has been explored before.
#
# While these similarities are not necessarily bad, they do indicate that the project may not be significantly novel or groundbreaking. As a result, it might face increased competition from more innovative proposals.
#
# **Innovative and Unique Aspects (Positive Impact): 30%**
#
# Despite the similarities, there are some aspects of this project that could set it apart:
#
# 1. **Integration with Farmer Feedback**: The proposal's emphasis on involving farmers in the development process and gathering feedback on the proposed solution is a step forward. This approach could lead to more effective and practical solutions.
# 2. **Scalability and Flexibility**: The system's design for small or medium-sized farms, with potential scalability to larger operations, is an asset.
#
# **Likelihood Score Breakdown:**
#
# * Similarity to previous projects: -20% (due to redundancy)
# * Innovative and unique aspects: +30% (due to practicality, flexibility, and farmer involvement)
#
# **Actionable Suggestions for Improvement:**
#
# To enhance the project's chances of grant approval, consider:
#
# 1. **Enhancing Innovation**: Explore more cutting-edge technologies or interdisciplinary approaches that could further differentiate this project from existing research.
# 2. **Better Aligning with Unmet Needs**: Conduct a deeper analysis of the dataset to identify specific gaps in current irrigation systems and address them directly in the proposal.
# 3. **Strengthening Justification**: Clearly articulate how this project addresses unique challenges, improves upon existing solutions, or offers a new perspective that justifies its funding over other proposals.
#
# By addressing these areas, you can improve the likelihood of grant approval for your project.
